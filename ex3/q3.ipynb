# %%
import gym
import numpy as np
import tensorflow.compat.v1 as tf
import collections
import os
from datetime import datetime
import time
import pdb

# optimized for Tf2
tf.disable_v2_behavior()

algorithm_name = "actor_critic"


# Actor
class PolicyNetwork:
    def __init__(self, state_size, action_size, name='policy_network'):
        self.state_size = state_size
        self.action_size = action_size
        self.learning_rate = tf.placeholder(tf.float32, [], name="learning_rate")

        with tf.variable_scope(name):
            self.state = tf.placeholder(tf.float32, [None, self.state_size], name="state")
            self.advantage_delta = tf.placeholder(tf.float32, name="advantage_delta")
            self.I_factor = tf.placeholder(tf.float32, name="I_factor")

            tf2_initializer = tf.keras.initializers.glorot_normal(seed=0)
            self.W1 = tf.get_variable("W1", [self.state_size, 12], initializer=tf2_initializer)
            self.b1 = tf.get_variable("b1", [12], initializer=tf2_initializer)
            self.W2 = tf.get_variable("W2", [12, self.action_size], initializer=tf2_initializer)
            self.b2 = tf.get_variable("b2", [self.action_size], initializer=tf2_initializer)

            self.Z1 = tf.add(tf.matmul(self.state, self.W1), self.b1)
            self.A1 = tf.nn.relu(self.Z1)
            self.output = tf.add(tf.matmul(self.A1, self.W2), self.b2)

            # Softmax probability distribution over actions
            self.actions_distribution = tf.squeeze(tf.nn.softmax(self.output))
            self.actions_log_probs = tf.math.log(self.actions_distribution)

            # Loss calculation  - for gradient ascent we minimize the negative loss. Loss = delta*I*ln(Pi)
            self.loss = self.I_factor * -tf.math.reduce_sum(self.advantage_delta * self.actions_log_probs)
            self.optimizer = tf.train.AdamOptimizer(learning_rate=self.learning_rate).minimize(self.loss)


# Critic
class ValueNetwork:
    def __init__(self, state_size, name='state_value_network'):
        self.state_size = state_size
        self.learning_rate = tf.placeholder(tf.float32, [], name="learning_rate")

        with tf.variable_scope(name):
            # Place holders for future calculation
            self.state = tf.placeholder(tf.float32, [None, self.state_size], name="state")
            self.I_factor = tf.placeholder(tf.float32, name="I_factor")
            self.advantage_delta = tf.placeholder(tf.float32, name="advantage_delta")

            tf2_initializer = tf.keras.initializers.glorot_normal(seed=0)
            self.W1 = tf.get_variable("W1", [self.state_size, 8], initializer=tf2_initializer)
            self.b1 = tf.get_variable("b1", [8], initializer=tf2_initializer)
            self.W2 = tf.get_variable("W2", [8, 1], initializer=tf2_initializer)
            self.b2 = tf.get_variable("b2", [1], initializer=tf2_initializer)

            self.Z1 = tf.add(tf.matmul(self.state, self.W1), self.b1)
            # self.A1 = tf.nn.relu(tf.layers.batch_normalization(self.Z1))
            self.A1 = tf.nn.relu(self.Z1)
            self.output = tf.add(tf.matmul(self.A1, self.W2), self.b2)

            # Loss calculation  - for gradient ascent we minimize the negative loss. Loss = delta*I*V
            self.loss = -self.advantage_delta * self.I_factor * self.output #
            self.optimizer = tf.train.AdamOptimizer(learning_rate=self.learning_rate).minimize(self.loss)


def run(discount_factor, policy_learning_rate, sv_learning_rate):
    env = gym.make('CartPole-v1')
    np.random.seed(SEED)
    env.seed(SEED)
    tf.set_random_seed(SEED)
    rewards, mean_rewards, losses = [], [], []
    # Define hyperparameters
    state_size = 6
    action_size = 3

    max_episodes = 5000
    max_episodes = 1000
    max_steps = 501
    discount_factor = discount_factor
    policy_learning_rate = policy_learning_rate
    sv_learning_rate = sv_learning_rate
    render = False

    # Initialize the policy and the state-value network
    tf.reset_default_graph()

    policy = PolicyNetwork(state_size, action_size)
    state_value = ValueNetwork(state_size)

    # Start training the agent with REINFORCE algorithm
    with tf.Session() as sess:

        sess.run(tf.global_variables_initializer())
        solved = False
        episode_rewards = np.zeros(max_episodes)
        average_rewards = 0.0
        stable = False
        # pdb.set_trace()
        max_r = 0
        max_e = 0
        for episode in range(max_episodes):

            # pdb.set_trace
            state = env.reset()
            padded_state = np.zeros((1, state_size))
            padded_state[0, :state.size] = state.flatten()
            state = padded_state


            state = state.reshape([1, state_size])
            I_factor = 1

            for step in range(max_steps):
                # pdb.set_trace()

                # Take action A ~ pi(*|S,thetha) and observe S',R.
                actions_distribution = sess.run(policy.actions_distribution, {policy.state: state})
                # print(np.arange(env.action_space.n))
                # print(actions_distribution[:action_size- env.action_space.n+1])
                softmax = np.exp(actions_distribution[:action_size- env.action_space.n+1]) / np.sum(np.exp(actions_distribution[:action_size- env.action_space.n+1]))
                # print(actions_distribution)
                try:
                    action = np.random.choice(np.arange(env.action_space.n), p=softmax)
                except:
                    # pdb.set_trace()
                    print("hey")

                next_state, reward, done, _ = env.step(action)
                padded_state = np.zeros((1, state_size))
                padded_state[0, :next_state.size] = next_state.flatten()
                next_state = padded_state
                # next_state = next_state.reshape([1, state_size])

                # action_one_hot = np.zeros(action_size)
                # action_one_hot[action] = 1
                episode_rewards[episode] += reward


                if np.mean(episode_rewards[(episode - 3):episode + 1]) > 450:
                      print("+++++++++++++++++++++++++++++++++")
                      policy_learning_rate *= 0.6
                      policy_learning_rate = max(policy_learning_rate, 7e-10)
                      sv_learning_rate *= 0.6
                      sv_learning_rate = max(sv_learning_rate, 7e-10)


                if render:
                    env.render()

                # Calculate state-value output for current state
                feed_dict = {state_value.state: state}
                value_current_state = sess.run(state_value.output, feed_dict)

                # Calculate state-value output for next state
                feed_dict = {state_value.state: next_state}
                value_next_state = sess.run(state_value.output, feed_dict)

                # Calculate advantage
                target = reward if done else reward + discount_factor * value_next_state
                advantage_delta = target - value_current_state

                # Update the state_value network weights
                feed_dict = {state_value.state: state, state_value.I_factor: I_factor,
                             state_value.advantage_delta: advantage_delta, state_value.learning_rate: sv_learning_rate}
                _, loss_state = sess.run([state_value.optimizer, state_value.loss], feed_dict)

                # Update the policy network weights
                feed_dict = {policy.state: state, policy.I_factor: I_factor,
                             policy.advantage_delta: advantage_delta, policy.learning_rate: policy_learning_rate}
                if stable:
                  # We prevent the network weights from changing after it is stable
                  loss_policy = sess.run(policy.loss, feed_dict)
                else:
                  _, loss_policy = sess.run([policy.optimizer, policy.loss], feed_dict)

                if done:

                    if episode > 98:
                        average_rewards = np.mean(episode_rewards[(episode - 99):episode + 1])
                    lst_5_avg = np.mean(episode_rewards[(episode - 5):episode + 1])
                    if lst_5_avg > 475:
                        stable = True
                    if average_rewards > max_r:
                      max_r = average_rewards
                      max_e = episode
                    print(
                        "Episode {} Reward: {} Average over 100 episodes: {}, max: {}, episode: {}".format(episode, episode_rewards[episode],
                                                                                     round(average_rewards, 2), max_r, max_e))
                    if average_rewards > 475:
                        print(' Solved at episode: ' + str(episode))
                        solved = True
                    break

                # I <- gamma*I
                I_factor *= discount_factor

                # S<-S'
                state = next_state

            if solved:
                break

            rewards.append(episode_rewards[episode])
            mean_rewards.append(average_rewards)
            losses.append(loss_policy)
    return episode, rewards, mean_rewards, losses


if __name__ == '__main__':
    SEED = 42
    # optimal_sv_lr = 0.0007
    # optimal_policy_lr = 0.0005

    # optimal_sv_lr = tf.keras.optimizers.schedules.ExponentialDecay(
    # initial_learning_rate,
    # decay_steps=100000,
    # decay_rate=0.96,
    # staircase=True)

    optimal_sv_lr = 0.0007
    # optimal_policy_lr = 0.01
    optimal_sv_lr = 0.001
    optimal_policy_lr = 0.001

    optimal_df = 0.99
    algorithm_name = "actor_critic"
    last_episode_a_c, rewards_a_c, mean_rewards_a_c, losses_a_c = run(discount_factor=optimal_df,
                                                      policy_learning_rate=optimal_policy_lr,
                                                      sv_learning_rate=optimal_sv_lr)
# Out:
# Episode 0 Reward: 29.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 1 Reward: 18.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 2 Reward: 11.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 3 Reward: 12.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 4 Reward: 60.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 5 Reward: 10.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 6 Reward: 24.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 7 Reward: 16.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 8 Reward: 21.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 9 Reward: 45.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 10 Reward: 22.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 11 Reward: 15.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 12 Reward: 21.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 13 Reward: 27.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 14 Reward: 16.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 15 Reward: 25.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 16 Reward: 45.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 17 Reward: 33.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 18 Reward: 41.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 19 Reward: 30.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 20 Reward: 23.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 21 Reward: 15.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 22 Reward: 32.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 23 Reward: 16.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 24 Reward: 25.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 25 Reward: 18.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 26 Reward: 24.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 27 Reward: 43.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 28 Reward: 18.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 29 Reward: 38.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 30 Reward: 23.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 31 Reward: 10.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 32 Reward: 14.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 33 Reward: 17.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 34 Reward: 29.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 35 Reward: 14.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 36 Reward: 20.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 37 Reward: 12.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 38 Reward: 25.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 39 Reward: 20.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 40 Reward: 15.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 41 Reward: 14.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 42 Reward: 22.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 43 Reward: 28.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 44 Reward: 34.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 45 Reward: 11.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 46 Reward: 39.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 47 Reward: 14.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 48 Reward: 17.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 49 Reward: 9.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 50 Reward: 20.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 51 Reward: 16.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 52 Reward: 39.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 53 Reward: 20.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 54 Reward: 10.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 55 Reward: 14.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 56 Reward: 18.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 57 Reward: 14.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 58 Reward: 20.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 59 Reward: 15.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 60 Reward: 34.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 61 Reward: 15.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 62 Reward: 33.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 63 Reward: 22.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 64 Reward: 13.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 65 Reward: 12.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 66 Reward: 11.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 67 Reward: 15.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 68 Reward: 17.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 69 Reward: 12.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 70 Reward: 50.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 71 Reward: 25.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 72 Reward: 16.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 73 Reward: 37.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 74 Reward: 29.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 75 Reward: 18.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 76 Reward: 23.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 77 Reward: 41.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 78 Reward: 23.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 79 Reward: 26.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 80 Reward: 18.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 81 Reward: 11.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 82 Reward: 16.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 83 Reward: 15.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 84 Reward: 18.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 85 Reward: 26.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 86 Reward: 20.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 87 Reward: 44.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode 88 Reward: 32.0 Average over 100 episodes: 0.0, max: 0, episode: 0
# Episode
# Episode 130 Reward: 63.0 Average over 100 episodes: 22.61, max: 23.34, episode: 99
# Episode 131 Reward: 14.0 Average over 100 episodes: 22.65, max: 23.34, episode: 99
# Episode 132 Reward: 22.0 Average over 100 episodes: 22.73, max: 23.34, episode: 99
# Episode 133 Reward: 52.0 Average over 100 episodes: 23.08, max: 23.34, episode: 99
# Episode 134 Reward: 39.0 Average over 100 episodes: 23.18, max: 23.34, episode: 99
# Episode 135 Reward: 29.0 Average over 100 episodes: 23.33, max: 23.34, episode: 99
# Episode 136 Reward: 18.0 Average over 100 episodes: 23.31, max: 23.34, episode: 99
# Episode 137 Reward: 27.0 Average over 100 episodes: 23.46, max: 23.46, episode: 137
# Episode 138 Reward: 42.0 Average over 100 episodes: 23.63, max: 23.63, episode: 138
# Episode 139 Reward: 14.0 Average over 100 episodes: 23.57, max: 23.63, episode: 138
# Episode 140 Reward: 24.0 Average over 100 episodes: 23.66, max: 23.66, episode: 140
# Episode 141 Reward: 28.0 Average over 100 episodes: 23.8, max: 23.8, episode: 141
# Episode 142 Reward: 19.0 Average over 100 episodes: 23.77, max: 23.8, episode: 141
# Episode 143 Reward: 20.0 Average over 100 episodes: 23.69, max: 23.8, episode: 141
# Episode 144 Reward: 35.0 Average over 100 episodes: 23.7, max: 23.8, episode: 141
# Episode 145 Reward: 14.0 Average over 100 episodes: 23.73, max: 23.8, episode: 141
# Episode 146 Reward: 19.0 Average over 100 episodes: 23.53, max: 23.8, episode: 141
# Episode 147 Reward: 15.0 Average over 100 episodes: 23.54, max: 23.8, episode: 141
# Episode 148 Reward: 21.0 Average over 100 episodes: 23.58, max: 23.8, episode: 141
# Episode 149 Reward: 14.0 Average over 100 episodes: 23.63, max: 23.8, episode: 141
# Episode 150 Reward: 13.0 Average over 100 episodes: 23.56, max: 23.8, episode: 141
# Episode 151 Reward: 12.0 Average over 100 episodes: 23.52, max: 23.8, episode: 141
# Episode 152 Reward: 18.0 Average over 100 episodes: 23.31, max: 23.8, episode: 141
# Episode 153 Reward: 10.0 Average over 100 episodes: 23.21, max: 23.8, episode: 141
# Episode 154 Reward: 16.0 Average over 100 episodes: 23.27, max: 23.8, episode: 141
# Episode 155 Reward: 45.0 Average over 100 episodes: 23.58, max: 23.8, episode: 141
# Episode 156 Reward: 10.0 Average over 100 episodes: 23.5, max: 23.8, episode: 141
# Episode 157 Reward: 26.0 Average over 100 episodes: 23.62, max: 23.8, episode: 141
# Episode 158 Reward: 26.0 Average over 100 episodes: 23.68, max: 23.8, episode: 141
# Episode 159 Reward: 19.0 Average over 100 episodes: 23.72, max: 23.8, episode: 141
# Episode 160 Reward: 16.0 Average over 100 episodes: 23.54, max: 23.8, episode: 141
# Episode 161 Reward: 14.0 Average over 100 episodes: 23.53, max: 23.8, episode: 141
# Episode 162 Reward: 24.0 Average over 100 episodes: 23.44, max: 23.8, episode: 141
# Episode 163 Reward: 15.0 Average over 100 episodes: 23.37, max: 23.8, episode: 141
# Episode 409 Reward: 19.0 Average over 100 episodes: 20.74, max: 24.09, episode: 169
# Episode 410 Reward: 16.0 Average over 100 episodes: 20.54, max: 24.09, episode: 169
# Episode 411 Reward: 13.0 Average over 100 episodes: 20.47, max: 24.09, episode: 169
# Episode 412 Reward: 25.0 Average over 100 episodes: 20.39, max: 24.09, episode: 169
# Episode 413 Reward: 15.0 Average over 100 episodes: 20.36, max: 24.09, episode: 169
# Episode 414 Reward: 48.0 Average over 100 episodes: 20.71, max: 24.09, episode: 169
# Episode 415 Reward: 13.0 Average over 100 episodes: 20.51, max: 24.09, episode: 169
# Episode 416 Reward: 14.0 Average over 100 episodes: 20.4, max: 24.09, episode: 169
# Episode 417 Reward: 19.0 Average over 100 episodes: 20.34, max: 24.09, episode: 169
# Episode 418 Reward: 14.0 Average over 100 episodes: 20.32, max: 24.09, episode: 169
# Episode 419 Reward: 15.0 Average over 100 episodes: 20.28, max: 24.09, episode: 169
# Episode 420 Reward: 14.0 Average over 100 episodes: 20.09, max: 24.09, episode: 169
# Episode 421 Reward: 12.0 Average over 100 episodes: 20.08, max: 24.09, episode: 169
# Episode 422 Reward: 22.0 Average over 100 episodes: 20.13, max: 24.09, episode: 169
# Episode 423 Reward: 25.0 Average over 100 episodes: 20.16, max: 24.09, episode: 169
# Episode 424 Reward: 16.0 Average over 100 episodes: 20.21, max: 24.09, episode: 169
# Episode 425 Reward: 23.0 Average over 100 episodes: 20.12, max: 24.09, episode: 169
# Episode 426 Reward: 18.0 Average over 100 episodes: 20.11, max: 24.09, episode: 169
# Episode 427 Reward: 14.0 Average over 100 episodes: 20.06, max: 24.09, episode: 169
# Episode 428 Reward: 16.0 Average over 100 episodes: 20.13, max: 24.09, episode: 169
# Episode 429 Reward: 17.0 Average over 100 episodes: 20.08, max: 24.09, episode: 169
# Episode 430 Reward: 11.0 Average over 100 episodes: 19.65, max: 24.09, episode: 169
# Episode 431 Reward: 20.0 Average over 100 episodes: 19.45, max: 24.09, episode: 169
# Episode 432 Reward: 11.0 Average over 100 episodes: 19.32, max: 24.09, episode: 169
# Episode 433 Reward: 14.0 Average over 100 episodes: 19.07, max: 24.09, episode: 169
# Episode 434 Reward: 32.0 Average over 100 episodes: 19.22, max: 24.09, episode: 169
# Episode 435 Reward: 15.0 Average over 100 episodes: 19.08, max: 24.09, episode: 169
# Episode 436 Reward: 18.0 Average over 100 episodes: 19.08, max: 24.09, episode: 169
# Episode 437 Reward: 28.0 Average over 100 episodes: 19.27, max: 24.09, episode: 169
# Episode 438 Reward: 17.0 Average over 100 episodes: 19.26, max: 24.09, episode: 169
# Episode 439 Reward: 21.0 Average over 100 episodes: 19.21, max: 24.09, episode: 169
# Episode 440 Reward: 22.0 Average over 100 episodes: 19.11, max: 24.09, episode: 169
# Episode 441 Reward: 13.0 Average over 100 episodes: 18.86, max: 24.09, episode: 169
# Episode 442 Reward: 23.0 Average over 100 episodes: 18.93, max: 24.09, episode: 169
# Episode 443 Reward: 46.0 Average over 100 episodes: 19.11, max: 24.09, episode: 169
# Episode 444 Reward: 35.0 Average over 100 episodes: 19.26, max: 24.09, episode: 169
# Episode 445 Reward: 19.0 Average over 100 episodes: 19.18, max: 24.09, episode: 169
# Episode 446 Reward: 15.0 Average over 100 episodes: 19.15, max: 24.09, episode: 169
# Episode 447 Reward: 16.0 Average over 100 episodes: 19.18, max: 24.09, episode: 169
# Episode 448 Reward: 15.0 Average over 100 episodes: 19.21, max: 24.09, episode: 169
# Episode 449 Reward: 16.0 Average over 100 episodes: 19.18, max: 24.09, episode: 169
# Episode 450 Reward: 14.0 Average over 100 episodes: 19.17, max: 24.09, episode: 169
# Episode 451 Reward: 63.0 Average over 100 episodes: 19.54, max: 24.09, episode: 169
# Episode 452 Reward: 24.0 Average over 100 episodes: 19.61, max: 24.09, episode: 169
# Episode 453 Reward: 11.0 Average over 100 episodes: 19.41, max: 24.09, episode: 169
# Episode 454 Reward: 44.0 Average over 100 episodes: 19.75, max: 24.09, episode: 169
# Episode 455 Reward: 18.0 Average over 100 episodes: 19.77, max: 24.09, episode: 169
# Episode 456 Reward: 26.0 Average over 100 episodes: 19.87, max: 24.09, episode: 169
# Episode 457 Reward: 40.0 Average over 100 episodes: 20.12, max: 24.09, episode: 169
# Episode 458 Reward: 25.0 Average over 100 episodes: 20.26, max: 24.09, episode: 169
# Episode 459 Reward: 13.0 Average over 100 episodes: 20.07, max: 24.09, episode: 169
# Episode 460 Reward: 43.0 Average over 100 episodes: 20.24, max: 24.09, episode: 169
# Episode 461 Reward: 16.0 Average over 100 episodes: 20.3, max: 24.09, episode: 169
# Episode 462 Reward: 18.0 Average over 100 episodes: 20.33, max: 24.09, episode: 169
# Episode 463 Reward: 14.0 Average over 100 episodes: 20.3, max: 24.09, episode: 169
# Episode 464 Reward: 18.0 Average over 100 episodes: 20.13, max: 24.09, episode: 169
# Episode 465 Reward: 16.0 Average over 100 episodes: 20.1, max: 24.09, episode: 169
# Episode 466 Reward: 20.0 Average over 100 episodes: 19.99, max: 24.09, episode: 169
# Episode 467 Reward: 33.0 Average over 100 episodes: 20.2, max: 24.09, episode: 169
# Episode 468 Reward: 17.0 Average over 100 episodes: 20.03, max: 24.09, episode: 169
# Episode 469 Reward: 12.0 Average over 100 episodes: 20.02, max: 24.09, episode: 169
# Episode 470 Reward: 11.0 Average over 100 episodes: 19.91, max: 24.09, episode: 169
# Episode 471 Reward: 21.0 Average over 100 episodes: 19.93, max: 24.09, episode: 169
# Episode 472 Reward: 15.0 Average over 100 episodes: 19.98, max: 24.09, episode: 169
# Episode 473 Reward: 45.0 Average over 100 episodes: 20.29, max: 24.09, episode: 169
# Episode 474 Reward: 15.0 Average over 100 episodes: 20.26, max: 24.09, episode: 169
# Episode 475 Reward: 34.0 Average over 100 episodes: 20.48, max: 24.09, episode: 169
# Episode 476 Reward: 22.0 Average over 100 episodes: 20.49, max: 24.09, episode: 169
# Episode 477 Reward: 17.0 Average over 100 episodes: 20.42, max: 24.09, episode: 169
# Episode 478 Reward: 18.0 Average over 100 episodes: 20.33, max: 24.09, episode: 169
# Episode 479 Reward: 44.0 Average over 100 episodes: 20.62, max: 24.09, episode: 169
# Episode 480 Reward: 34.0 Average over 100 episodes: 20.81, max: 24.09, episode: 169
# Episode 481 Reward: 37.0 Average over 100 episodes: 21.05, max: 24.09, episode: 169
# Episode 482 Reward: 25.0 Average over 100 episodes: 21.14, max: 24.09, episode: 169
# Episode 483 Reward: 18.0 Average over 100 episodes: 21.18, max: 24.09, episode: 169
# Episode 484 Reward: 10.0 Average over 100 episodes: 21.18, max: 24.09, episode: 169
# Episode 485 Reward: 14.0 Average over 100 episodes: 21.15, max: 24.09, episode: 169
# Episode 486 Reward: 22.0 Average over 100 episodes: 21.09, max: 24.09, episode: 169
# Episode 487 Reward: 13.0 Average over 100 episodes: 20.92, max: 24.09, episode: 169
# Episode 488 Reward: 14.0 Average over 100 episodes: 20.79, max: 24.09, episode: 169
# Episode 489 Reward: 46.0 Average over 100 episodes: 20.9, max: 24.09, episode: 169
# Episode 490 Reward: 27.0 Average over 100 episodes: 21.06, max: 24.09, episode: 169
# Episode 491 Reward: 17.0 Average over 100 episodes: 21.02, max: 24.09, episode: 169
# Episode 492 Reward: 13.0 Average over 100 episodes: 21.06, max: 24.09, episode: 169
# Episode 493 Reward: 17.0 Average over 100 episodes: 21.08, max: 24.09, episode: 169
# Episode 494 Reward: 11.0 Average over 100 episodes: 21.06, max: 24.09, episode: 169
# Episode 495 Reward: 29.0 Average over 100 episodes: 21.19, max: 24.09, episode: 169
# Episode 496 Reward: 22.0 Average over 100 episodes: 21.2, max: 24.09, episode: 169
# Episode 497 Reward: 19.0 Average over 100 episodes: 21.29, max: 24.09, episode: 169
# Episode 498 Reward: 34.0 Average over 100 episodes: 21.54, max: 24.09, episode: 169
# Episode 499 Reward: 37.0 Average over 100 episodes: 21.4, max: 24.09, episode: 169
# Episode 500 Reward: 15.0 Average over 100 episodes: 21.31, max: 24.09, episode: 169
# Episode 501 Reward: 24.0 Average over 100 episodes: 21.34, max: 24.09, episode: 169
# Episode 502 Reward: 28.0 Average over 100 episodes: 21.31, max: 24.09, episode: 169
# Episode 503 Reward: 20.0 Average over 100 episodes: 21.33, max: 24.09, episode: 169
# Episode 504 Reward: 20.0 Average over 100 episodes: 21.4, max: 24.09, episode: 169
# Episode 505 Reward: 16.0 Average over 100 episodes: 21.43, max: 24.09, episode: 169
# Episode 506 Reward: 14.0 Average over 100 episodes: 21.43, max: 24.09, episode: 169
# Episode 507 Reward: 30.0 Average over 100 episodes: 21.61, max: 24.09, episode: 169
# Episode 508 Reward: 11.0 Average over 100 episodes: 21.59, max: 24.09, episode: 169
# Episode 509 Reward: 26.0 Average over 100 episodes: 21.66, max: 24.09, episode: 169
# Episode 510 Reward: 57.0 Average over 100 episodes: 22.07, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 867 Reward: 9.0 Average over 100 episodes: 9.3, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 868 Reward: 9.0 Average over 100 episodes: 9.29, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 869 Reward: 10.0 Average over 100 episodes: 9.29, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 870 Reward: 10.0 Average over 100 episodes: 9.29, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 871 Reward: 10.0 Average over 100 episodes: 9.3, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 872 Reward: 9.0 Average over 100 episodes: 9.29, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 873 Reward: 9.0 Average over 100 episodes: 9.29, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 874 Reward: 9.0 Average over 100 episodes: 9.29, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 875 Reward: 8.0 Average over 100 episodes: 9.26, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 876 Reward: 9.0 Average over 100 episodes: 9.26, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 877 Reward: 11.0 Average over 100 episodes: 9.28, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 878 Reward: 10.0 Average over 100 episodes: 9.29, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 879 Reward: 10.0 Average over 100 episodes: 9.3, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 880 Reward: 8.0 Average over 100 episodes: 9.29, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 881 Reward: 8.0 Average over 100 episodes: 9.28, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 882 Reward: 8.0 Average over 100 episodes: 9.27, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 883 Reward: 10.0 Average over 100 episodes: 9.27, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 884 Reward: 8.0 Average over 100 episodes: 9.25, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 885 Reward: 10.0 Average over 100 episodes: 9.25, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 886 Reward: 10.0 Average over 100 episodes: 9.25, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 887 Reward: 10.0 Average over 100 episodes: 9.27, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 888 Reward: 9.0 Average over 100 episodes: 9.27, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 889 Reward: 10.0 Average over 100 episodes: 9.27, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 890 Reward: 10.0 Average over 100 episodes: 9.28, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 891 Reward: 10.0 Average over 100 episodes: 9.3, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 892 Reward: 10.0 Average over 100 episodes: 9.29, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 893 Reward: 9.0 Average over 100 episodes: 9.28, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 894 Reward: 10.0 Average over 100 episodes: 9.3, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 895 Reward: 9.0 Average over 100 episodes: 9.3, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 896 Reward: 9.0 Average over 100 episodes: 9.29, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 897 Reward: 10.0 Average over 100 episodes: 9.31, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 898 Reward: 8.0 Average over 100 episodes: 9.29, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 899 Reward: 10.0 Average over 100 episodes: 9.3, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 900 Reward: 9.0 Average over 100 episodes: 9.29, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 901 Reward: 8.0 Average over 100 episodes: 9.29, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 902 Reward: 10.0 Average over 100 episodes: 9.3, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 903 Reward: 10.0 Average over 100 episodes: 9.31, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 904 Reward: 9.0 Average over 100 episodes: 9.31, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 905 Reward: 9.0 Average over 100 episodes: 9.3, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 906 Reward: 10.0 Average over 100 episodes: 9.3, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 907 Reward: 9.0 Average over 100 episodes: 9.3, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 908 Reward: 9.0 Average over 100 episodes: 9.31, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 909 Reward: 10.0 Average over 100 episodes: 9.32, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 910 Reward: 10.0 Average over 100 episodes: 9.32, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 911 Reward: 9.0 Average over 100 episodes: 9.32, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 912 Reward: 9.0 Average over 100 episodes: 9.3, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 913 Reward: 9.0 Average over 100 episodes: 9.31, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 914 Reward: 10.0 Average over 100 episodes: 9.32, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 915 Reward: 10.0 Average over 100 episodes: 9.34, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 916 Reward: 9.0 Average over 100 episodes: 9.34, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 917 Reward: 9.0 Average over 100 episodes: 9.33, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 918 Reward: 10.0 Average over 100 episodes: 9.33, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 919 Reward: 9.0 Average over 100 episodes: 9.33, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 920 Reward: 9.0 Average over 100 episodes: 9.33, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 921 Reward: 9.0 Average over 100 episodes: 9.32, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 922 Reward: 8.0 Average over 100 episodes: 9.31, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 923 Reward: 10.0 Average over 100 episodes: 9.31, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 924 Reward: 8.0 Average over 100 episodes: 9.3, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 925 Reward: 10.0 Average over 100 episodes: 9.31, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 926 Reward: 9.0 Average over 100 episodes: 9.32, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 927 Reward: 10.0 Average over 100 episodes: 9.31, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 928 Reward: 10.0 Average over 100 episodes: 9.32, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 929 Reward: 10.0 Average over 100 episodes: 9.34, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 930 Reward: 10.0 Average over 100 episodes: 9.34, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 931 Reward: 10.0 Average over 100 episodes: 9.35, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 932 Reward: 11.0 Average over 100 episodes: 9.36, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 933 Reward: 9.0 Average over 100 episodes: 9.36, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 934 Reward: 10.0 Average over 100 episodes: 9.37, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 935 Reward: 10.0 Average over 100 episodes: 9.39, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 936 Reward: 9.0 Average over 100 episodes: 9.38, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 937 Reward: 8.0 Average over 100 episodes: 9.38, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 938 Reward: 9.0 Average over 100 episodes: 9.38, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 939 Reward: 10.0 Average over 100 episodes: 9.38, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 940 Reward: 8.0 Average over 100 episodes: 9.36, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 941 Reward: 9.0 Average over 100 episodes: 9.35, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 942 Reward: 11.0 Average over 100 episodes: 9.36, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 943 Reward: 10.0 Average over 100 episodes: 9.37, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 944 Reward: 10.0 Average over 100 episodes: 9.38, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 945 Reward: 10.0 Average over 100 episodes: 9.38, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 946 Reward: 10.0 Average over 100 episodes: 9.38, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 947 Reward: 9.0 Average over 100 episodes: 9.38, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 948 Reward: 10.0 Average over 100 episodes: 9.38, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 949 Reward: 9.0 Average over 100 episodes: 9.37, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 950 Reward: 9.0 Average over 100 episodes: 9.36, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 951 Reward: 10.0 Average over 100 episodes: 9.37, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 952 Reward: 9.0 Average over 100 episodes: 9.36, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 953 Reward: 9.0 Average over 100 episodes: 9.36, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 954 Reward: 10.0 Average over 100 episodes: 9.38, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 955 Reward: 9.0 Average over 100 episodes: 9.37, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 956 Reward: 9.0 Average over 100 episodes: 9.37, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 957 Reward: 9.0 Average over 100 episodes: 9.36, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 958 Reward: 9.0 Average over 100 episodes: 9.37, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 959 Reward: 10.0 Average over 100 episodes: 9.39, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 960 Reward: 10.0 Average over 100 episodes: 9.41, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 961 Reward: 10.0 Average over 100 episodes: 9.41, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 962 Reward: 9.0 Average over 100 episodes: 9.4, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 963 Reward: 10.0 Average over 100 episodes: 9.39, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 964 Reward: 10.0 Average over 100 episodes: 9.41, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 965 Reward: 10.0 Average over 100 episodes: 9.43, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 966 Reward: 9.0 Average over 100 episodes: 9.42, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 967 Reward: 9.0 Average over 100 episodes: 9.42, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 968 Reward: 11.0 Average over 100 episodes: 9.44, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 969 Reward: 8.0 Average over 100 episodes: 9.42, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 970 Reward: 10.0 Average over 100 episodes: 9.42, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 971 Reward: 11.0 Average over 100 episodes: 9.43, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 972 Reward: 9.0 Average over 100 episodes: 9.43, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 973 Reward: 10.0 Average over 100 episodes: 9.44, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 974 Reward: 8.0 Average over 100 episodes: 9.43, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 975 Reward: 10.0 Average over 100 episodes: 9.45, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 976 Reward: 10.0 Average over 100 episodes: 9.46, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 977 Reward: 9.0 Average over 100 episodes: 9.44, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 978 Reward: 9.0 Average over 100 episodes: 9.43, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 979 Reward: 10.0 Average over 100 episodes: 9.43, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 980 Reward: 9.0 Average over 100 episodes: 9.44, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 981 Reward: 10.0 Average over 100 episodes: 9.46, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 982 Reward: 9.0 Average over 100 episodes: 9.47, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 983 Reward: 9.0 Average over 100 episodes: 9.46, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 984 Reward: 9.0 Average over 100 episodes: 9.47, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 985 Reward: 9.0 Average over 100 episodes: 9.46, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 986 Reward: 9.0 Average over 100 episodes: 9.45, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 987 Reward: 9.0 Average over 100 episodes: 9.44, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 988 Reward: 8.0 Average over 100 episodes: 9.43, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 989 Reward: 8.0 Average over 100 episodes: 9.41, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 990 Reward: 10.0 Average over 100 episodes: 9.41, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 991 Reward: 9.0 Average over 100 episodes: 9.4, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 992 Reward: 10.0 Average over 100 episodes: 9.4, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 993 Reward: 8.0 Average over 100 episodes: 9.39, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 994 Reward: 9.0 Average over 100 episodes: 9.38, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 995 Reward: 9.0 Average over 100 episodes: 9.38, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 996 Reward: 9.0 Average over 100 episodes: 9.38, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 997 Reward: 10.0 Average over 100 episodes: 9.38, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 998 Reward: 9.0 Average over 100 episodes: 9.39, max: 24.09, episode: 169
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Episode 999 Reward: 9.0 Average over 100 episodes: 9.38, max: 24.09, episode: 169
